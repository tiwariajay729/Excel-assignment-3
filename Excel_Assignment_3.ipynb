# %% [markdown]
# Q1 - Member Duration Month

# %% [markdown]
# Add a column  Membership_Duration_Months active Assume 1 month = 30 days Use  Start_Date and End_Date

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q2 - Referral Impact - Yes/NO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q2b - Pivot for Avg_Monthly_fee

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q3 - Revenue Calculation Family & Premium

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q3b City wise Breakup

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q4 - Identify Low Engagement Members - Use Conditional Formatting to highlight
#
# Members with Attendance < 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q4b - AND whose Membership_Duration_Months >= 6
# These are long-term but inactive users—flag them.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q4c - Attendance < 8 and membership duration >= 6, These are long-term but inactive users—flag them.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q5 - 5. Segment Profitability Dashboard The management at PowerFit India wants deeper insights into which combinations of member traits (like city, membership type, and referral status) bring in the most revenue.
#
# 5 (1)  - Which City + Membership Type + Referral combinations are most profitable?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q 5 (2) - What is the average revenue per member across different segments?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q5 C Where should PowerFit focus its marketing on referral programs?

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# They should focus its marketing on 3 cities - hyderabad, Kolkata and Pune.

# %% [markdown]
# Q5 (3 - 2) Make your dashboard interactive using Slicers and add a visual chart for quick insights.

# %% [markdown]
# ![Slicer.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Q6 - Gender & Age Distribution - Create two Pivot Tables -
#      Gender-wise count of members per city -
#      Age distribution across Membership -
#      Types 18–30 = Youth 31–45 = Adult 46+ = Seniors

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
